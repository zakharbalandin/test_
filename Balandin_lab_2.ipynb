# %%
import sympy as sp
from sympy.abc import x,pi
from scipy import optimize
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:e69da0dc-c7db-4582-840e-d0c55e9c4eae.png)

# %%
x=sp.symbols('x')
I1 = sp.integrate(x**2+1,(x,0,1))
I2 = sp.integrate(3-x,(x,1,2))
I3 = sp.integrate(1,(x,0,2))
print(float(I1+I2-I3))

x=np.linspace(0,2,100)
fu=x**2+1
y1=3-x
y2=1

plt.plot(x,fu)
plt.plot(x,y1)
plt.plot(x,y2+0*x)
plt.grid()
plt.show
# Out:
# 0.8333333333333334
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ![image.png](attachment:c8de56f5-8f95-4f4a-9001-c3a85f3b75de.png)

# %%
from numpy import *
import matplotlib.pyplot as plt



x=sp.symbols('x')
t=sp.symbols('t')
fu1=sp.cos(t)**3
fu2=sp.sin(t)**3
fu1=sp.diff(fu1,t,1)


I1 = sp.integrate(fu1*fu2,(t,0,pi))
I2 = sp.integrate(fu1*fu2,(t,pi,2*pi))
print(abs(float(I1+I2)))


t=linspace(0,2*pi,1000)
x=cos(t)**3
y=sin(t)**3
plt.axis('equal')
plt.plot(x,y,'m')
plt.grid(True)
# Out:
# 1.1780972450961724

# %% [markdown]
# ![image.png](attachment:b2bdb683-7e82-4ae2-9738-3d843bdd4ea5.png)

# %%
from numpy import *
import matplotlib.pyplot as plt



x=sp.symbols('x')
t=sp.symbols('t')
fu1=2
fu2=sp.diff(fu1,t,1)
I1 = 1/2*sp.integrate(fu1**2,(t,pi/4,3*pi/4))

fu1=1

I2 = 1/2*sp.integrate(fu1**2,(t,pi/4,3*pi/4))
print(abs(float(I1-I2)))


t=linspace(0,2*pi,100)
r=1
x=r*cos(t)
y=r*sin(t)
plt.plot(x,y)

r=2
x=r*cos(t)
y=r*sin(t)
plt.plot(x,y)
e=linspace(0,3,100)
x=e*cos(pi/4)
y=e*sin(pi/4)
plt.plot(x,y)
x=e*cos(3*pi/4)
y=e*sin(3*pi/4)
plt.plot(x,y)

plt.axis('equal')
plt.grid(True)
plt.show
# Out:
# 2.356194490192345
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ![image.png](attachment:b13e5007-4bdc-47b4-add5-f14b80405fc4.png)

# %%
from numpy import *
import matplotlib.pyplot as plt

x=sp.symbols('x')
t=sp.symbols('t')
fu1=sp.cos(t)**3
fu2=sp.sin(t)**3
fu1=sp.diff(fu1,t,1)

I1 = sp.integrate(fu1*fu2,(t,0,pi))
I2 = sp.integrate(fu1*fu2,(t,pi,2*pi))
print(abs(float(I1+I2)))

t=linspace(0,2*pi,1000)
x=cos(t)**3
y=sin(t)**3
plt.axis('equal')
plt.plot(x,y,'r')
plt.grid(True)
# Out:
# 1.1780972450961724

# %% [markdown]
# Индивидуальные задания
# Вариант 4

# %% [markdown]
# ![image.png](attachment:9b59d100-9ac3-4e4b-8bb0-54ed7a421582.png)

# %%
from numpy import *
import matplotlib.pyplot as plt

x=sp.symbols('x')
t=sp.symbols('t')
fu1=6*sp.cos(t)
fu2=3*2**(1/2)
a=sp.solve(fu1-fu2)

x = 3*2**(1/2)*sp.sin(t)
y = 3*2**(1/2)*sp.cos(t)

x1 = sp.diff(x,t,1)
y1 = sp.diff(y,t,1)
print(a, "Точки пересечения")

I1 = sp.integrate((x1**2+y1**2)**(1/2),(t,0.785398163397450, 5.49778714378214))

print(2*np.pi*3*(2)**(1/2) - abs(float(I1)))

x=linspace(0,2*pi,100)





t=linspace(0,2*pi,1000)
r=6*cos(t)

x=r*cos(t)

y=r*sin(t)



plt.plot(x,y,'r')


t=linspace(0,2*pi,1000)
r=3*2**(1/2)
x=r*cos(t)
y=r*sin(t)



plt.plot(x,y,'m')
t=0.785398163397450
r=3*2**(1/2)
x=r*cos(t)
y=r*sin(t)

plt.plot(x,y,'yo')



plt.plot(x,y)
t=5.49778714378214
r=3*2**(1/2)
x=r*cos(t)
y=r*sin(t)

plt.plot(x,y,'yo')


plt.axis('equal')
plt.grid(True)
# Out:
# [0.785398163397447, 5.49778714378214] Точки пересечения
# 6.664324407237547

# %% [markdown]
# ![image.png](attachment:5061e0de-09d8-429e-9dd7-246ab04404cd.png)

# %%
from numpy import *
import matplotlib.pyplot as plt



x=sp.symbols('x')

fu1=x**(1/3)
fu2=8
I1 = sp.integrate(fu1**2,(x,0,4))
I2 = sp.integrate(fu2**2,(x,0,4))

print(pi*abs(float(I2-I1)))


x=linspace(0,8,1000)
y1=x**(1/3)
plt.plot(x,y1)
x=linspace(0,2,1000)
y2=0*x + 8
plt.plot(y2,x)
x=linspace(0,8,1000)
plt.plot(x,x*0)
plt.axis('equal')
plt.grid(True)
# Out:
# 785.2485574896132
